# %% [markdown]
# # USING PRETRAINED EMBEDDINGS

# %%
# gensim 
from gensim.models import KeyedVectors

#LOAD WORD2VEC MODEL
WORD2VEC_MODEL="/mnt/volume/GoogleNews-vectors-negative300.bin"

#The vectors can also be instantiated from an existing file on disk in the original Google’s word2vec format as a KeyedVectors instance
word2vec = KeyedVectors.load_word2vec_format(WORD2VEC_MODEL, binary=True) #float32

# %%
word2vec['paris']
# Out:
# array([-3.55468750e-01,  4.61425781e-02,  8.05664062e-02,  4.37500000e-01,
#         1.04980469e-02,  2.18750000e-01, -1.51367188e-01, -1.09375000e-01,
#        -2.28515625e-01,  5.76171875e-02, -2.24609375e-01, -2.65625000e-01,
#        -3.95507812e-02, -1.37695312e-01, -8.30078125e-02,  1.52343750e-01,
#         5.76171875e-02,  4.12597656e-02, -3.34472656e-02,  1.81640625e-01,
#        -2.67578125e-01, -2.12890625e-01,  1.66992188e-01,  5.37109375e-02,
#        -1.92382812e-01,  7.42187500e-02, -1.80664062e-01,  3.90625000e-02,
#        -4.83398438e-02, -3.35937500e-01, -1.35742188e-01, -1.97265625e-01,
#        -1.99218750e-01, -9.66796875e-02, -1.11328125e-01, -5.27343750e-02,
#        -4.90722656e-02,  2.69531250e-01, -4.71191406e-02, -1.55273438e-01,
#        -1.30859375e-01, -1.82617188e-01,  3.88671875e-01,  3.43750000e-01,
#         3.47656250e-01, -1.12304688e-01,  1.42578125e-01, -6.68945312e-02,
# ...

# %%
word2vec.most_similar(positive=['woman', 'king'], negative=['man'])
# Out:
# [('queen', 0.7118192315101624),
#  ('monarch', 0.6189674139022827),
#  ('princess', 0.5902431011199951),
#  ('crown_prince', 0.5499460697174072),
#  ('prince', 0.5377321839332581),
#  ('kings', 0.5236844420433044),
#  ('Queen_Consort', 0.5235945582389832),
#  ('queens', 0.5181134343147278),
#  ('sultan', 0.5098593235015869),
#  ('monarchy', 0.5087411403656006)]

# %%
word2vec.doesnt_match("breakfast cereal dinner lunch".split())
# Out:
# 'cereal'

# %%
list(word2vec.vocab.keys())[100:110]
# Out:
# ['company',
#  'any',
#  'team',
#  'against',
#  'off',
#  'This',
#  'most',
#  'made',
#  'through',
#  'make']

# %%
word2vec.most_similar("italy")
# Out:
# [('juve', 0.6816889643669128),
#  ('spain', 0.6797661781311035),
#  ('barcelona', 0.6611632108688354),
#  ('italians', 0.6562130451202393),
#  ('juventus', 0.6556533575057983),
#  ('real_madrid', 0.6542579531669617),
#  ('sweden', 0.6493675708770752),
#  ('england', 0.6482644081115723),
#  ('madrid', 0.6466624736785889),
#  ('italian', 0.646099328994751)]

# %%
word2vec.most_similar("milan")
# Out:
# [('barca', 0.7833462953567505),
#  ('juve', 0.7734659910202026),
#  ('wenger', 0.7527397871017456),
#  ('real_madrid', 0.7516225576400757),
#  ('chelsea', 0.7489095330238342),
#  ('madrid', 0.7485138177871704),
#  ('juventus', 0.746327817440033),
#  ('messi', 0.7446121573448181),
#  ('liverpool', 0.7402892708778381),
#  ('man_utd', 0.7396901249885559)]

# %%
word2vec.similarity("girl","woman")
# Out:
# 0.7494640637680032

# %%
word2vec.similarity("girl","man")
# Out:
# 0.5921714079716728

# %%
word2vec.similarity("girl","car")
# Out:
# 0.223298188867882

# %%
word2vec.similarity("bus","car")
# Out:
# 0.46933710390321054
